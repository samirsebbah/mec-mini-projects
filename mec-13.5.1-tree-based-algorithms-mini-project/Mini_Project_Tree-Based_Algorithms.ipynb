# %% [markdown]
# # Mini Project: Tree-Based Algorithms

# %% [markdown]
# ## The "German Credit" Dataset

# %% [markdown]
# ### Dataset Details

# %% [markdown]
# This dataset has two classes (these would be considered labels in Machine Learning terms) to describe the worthiness of a personal loan: "Good" or "Bad". There are predictors related to attributes, such as: checking account status, duration, credit history, purpose of the loan, amount of the loan, savings accounts or bonds, employment duration, installment rate in percentage of disposable income, personal information, other debtors/guarantors, residence duration, property, age, other installment plans, housing, number of existing credits, job information, number of people being liable to provide maintenance for, telephone, and foreign worker status.
#
# Many of these predictors are discrete and have been expanded into several 0/1 indicator variables (a.k.a. they have been one-hot-encoded).
#
# This dataset has been kindly provided by Professor Dr. Hans Hofmann of the University of Hamburg, and can also be found on the UCI Machine Learning Repository.

# %% [markdown]
# ## Decision Trees

# %% [markdown]
#  As we have learned in the previous lectures, Decision Trees as a family of algorithms (irrespective to the particular implementation) are powerful algorithms that can produce models with a predictive accuracy higher than that produced by linear models, such as Linear or Logistic Regression. Primarily, this is due to the fact the DT's can model nonlinear relationships, and also have a number of tuning paramters, that allow for the practicioner to achieve the best possible model. An added bonus is the ability to visualize the trained Decision Tree model, which allows for some insight into how the model has produced the predictions that it has. One caveat here, to keep in mind, is that sometimes, due to the size of the dataset (both in the sense of the number of records, as well as the number of features), the visualization might prove to be very large and complex, increasing the difficulty of interpretation.

# %% [markdown]
# To give you a very good example of how Decision Trees can be visualized and interpreted, we would strongly recommend that, before continuing on with solving the problems in this Mini Project, you take the time to read this fanstastic, detailed and informative blog post: http://explained.ai/decision-tree-viz/index.html

# %% [markdown]
# ## Building Your First Decision Tree Model

# %% [markdown]
# So, now it's time to jump straight into the heart of the matter. Your first task, is to build a Decision Tree model, using the aforementioned "German Credit" dataset, which contains 1,000 records, and 62 columns (one of them presents the labels, and the other 61 present the potential features for the model.)

# %% [markdown]
# For this task, you will be using the scikit-learn library, which comes already pre-installed with the Anaconda Python distribution. In case you're not using that, you can easily install it using pip.

# %% [markdown]
# Before embarking on creating your first model, we would strongly encourage you to read the short tutorial for Decision Trees in scikit-learn (http://scikit-learn.org/stable/modules/tree.html), and then dive a bit deeper into the documentation of the algorithm itself (http://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html).

# %% [markdown]
# Also, since you want to be able to present the results of your model, we suggest you take a look at the tutorial for accuracy metrics for classification models (http://scikit-learn.org/stable/modules/model_evaluation.html#classification-report) as well as the more detailed documentation (http://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification_report.html).
#
# Finally, an *amazing* resource that explains the various classification model accuracy metrics, as well as the relationships between them, can be found on Wikipedia: https://en.wikipedia.org/wiki/Confusion_matrix

# %% [markdown]
# (Note: as you've already learned in the Logistic Regression mini project, a standard practice in Machine Learning for achieving the best possible result when training a model is to use hyperparameter tuning, through Grid Search and k-fold Cross Validation. We strongly encourage you to use it here as well, not just because it's standard practice, but also becuase it's not going to be computationally to intensive, due to the size of the dataset that you're working with. Our suggestion here is that you split the data into 70% training, and 30% testing. Then, do the hyperparameter tuning and Cross Validation on the training set, and afterwards to a final test on the testing set.)

# %% [markdown]
# ### Now we pass the torch onto you! You can start building your first Decision Tree model! :)

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn import metrics 
from sklearn.model_selection import cross_val_score

# %%
df = pd.read_csv('GermanCredit.csv.zip', compression='zip')

X = df.drop("Class", axis=1)
y = df["Class"]

print(y) 
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=43) 

# k fold cv
def best_tree_depth():
    k_folds = 10
    depth = []
    for i in range(3,20):
        clf = DecisionTreeClassifier(max_depth=i)
        scores = cross_val_score(estimator=clf, X=X_train, y=y_train, cv=k_folds, n_jobs=7)
        depth.append((i,scores.mean()))
    print(depth)

    from operator import itemgetter
    best_config = max(depth, key=itemgetter(1))
    return best_config[0]

best_tree_depth = best_tree_depth()
# Out:
# 0      Good
# 1       Bad
# 2      Good
# 3      Good
# 4       Bad
#        ...
# 995    Good
# 996    Good
# 997    Good
# 998     Bad
# 999    Good
# Name: Class, Length: 1000, dtype: object
# [(3, 0.68), (4, 0.6914285714285715), (5, 0.6957142857142858), (6, 0.6942857142857143), (7, 0.7057142857142856), (8, 0.6714285714285715), (9, 0.6914285714285714), (10, 0.6757142857142857), (11, 0.6871428571428572), (12, 0.6842857142857144), (13, 0.6671428571428571), (14, 0.6742857142857144), (15, 0.6742857142857143), (16, 0.6514285714285715), (17, 0.68), (18, 0.6742857142857144), (19, 0.6685714285714287)]

# %%
dtree_clf = DecisionTreeClassifier (max_depth = best_tree_depth)

# Train Decision Tree Classifer
dtree_clf = dtree_clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = dtree_clf.predict(X_test)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.6566666666666666

# %%
# grid search cv 
parameters = {'max_depth':range(2,10)}
dtree_clf_gs_cv = GridSearchCV(DecisionTreeClassifier(), parameters, n_jobs=8)
dtree_clf_gs_cv.fit(X=X, y=y)
best_model = dtree_clf_gs_cv.best_estimator_
print (dtree_clf_gs_cv.best_score_, dtree_clf_gs_cv.best_params_)
# Out:
# 0.713 {'max_depth': 5}

# %% [markdown]
# ### After you've built the best model you can, now it's time to visualize it!

# %% [markdown]
# Rememeber that amazing blog post from a few paragraphs ago, that demonstrated how to visualize and interpret the results of your Decision Tree model. We've seen that this can perform very well, but let's see how it does on the "German Credit" dataset that we're working on, due to it being a bit larger than the one used by the blog authors.

# %% [markdown]
# First, we're going to need to install their package. If you're using Anaconda, this can be done easily by running:

# %%
! pip install dtreeviz
! pip install pydotplus
! pip install graphviz

# %% [markdown]
# If for any reason this way of installing doesn't work for you straight out of the box, please refer to the more detailed documentation here: https://github.com/parrt/dtreeviz

# %% [markdown]
# Now you're ready to visualize your Decision Tree model! Please feel free to use the blog post for guidance and inspiration!

# %%
from sklearn.tree import export_graphviz
from six import StringIO 
from IPython.display import Image  
import pydotplus

dot_data = StringIO()
export_graphviz(dtree_clf, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names = X.columns,class_names=['Good','Bad'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('loan.png')
Image(graph.create_png())

# %% [markdown]
# ## Random Forests

# %% [markdown]
# As discussed in the lecture videos, Decision Tree algorithms also have certain undesireable properties. Mainly the have low bias, which is good, but tend to have high variance - which is *not* so good (more about this problem here: https://en.wikipedia.org/wiki/Bias%E2%80%93variance_tradeoff).

# %% [markdown]
# Noticing these problems, the late Professor Leo Breiman, in 2001, developed the Random Forests algorithm, which mitigates these problems, while at the same time providing even higher predictive accuracy than the majority of Decision Tree algorithm implementations. While the curriculum contains two excellent lectures on Random Forests, if you're interested, you can dive into the original paper here: https://link.springer.com/content/pdf/10.1023%2FA%3A1010933404324.pdf.

# %% [markdown]
# In the next part of this assignment, your are going to use the same "German Credit" dataset to train, tune, and measure the performance of a Random Forests model. You will also see certain functionalities that this model, even though it's a bit of a "black box", provides for some degree of interpretability.

# %% [markdown]
# First, let's build a Random Forests model, using the same best practices that you've used for your Decision Trees model. You can reuse the things you've already imported there, so no need to do any re-imports, new train/test splits, or loading up the data again.

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfclf = RandomForestClassifier(n_estimators = 100)
rfclf.fit(X_train, y_train)
y_pred = rfclf.predict(X_test)

print("accuracy score ", metrics.accuracy_score(y_test, y_pred))
# Out:
# accuracy score  0.7733333333333333

# %% [markdown]
# As mentioned, there are certain ways to "peek" into a model created by the Random Forests algorithm. The first, and most popular one, is the Feature Importance calculation functionality. This allows the ML practitioner to see an ordering of the importance of the features that have contributed the most to the predictive accuracy of the model.
#
# You can see how to use this in the scikit-learn documentation (http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html#sklearn.ensemble.RandomForestClassifier.feature_importances_). Now, if you tried this, you would just get an ordered table of not directly interpretable numeric values. Thus, it's much more useful to show the feature importance in a visual way. You can see an example of how that's done here: http://scikit-learn.org/stable/auto_examples/ensemble/plot_forest_importances.html#sphx-glr-auto-examples-ensemble-plot-forest-importances-py
#
# Now you try! Let's visualize the importance of features from your Random Forests model!

# %%
# Your code here
import numpy as np
import matplotlib.pyplot as plt 
 
std = np.std([tree.feature_importances_ for tree in rfclf.estimators_], axis=0)

rfclf_importances = pd.Series(rfclf.feature_importances_, index=X.columns)

fig, ax = plt.subplots()
rfclf_importances.plot.bar(yerr=std, ax=ax)
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()

# %% [markdown]
# A final method for gaining some insight into the inner working of your Random Forests models is a so-called Partial Dependence Plot. The Partial Dependence Plot (PDP or PD plot) shows the marginal effect of a feature on the predicted outcome of a previously fit model. The prediction function is fixed at a few values of the chosen features and averaged over the other features. A partial dependence plot can show if the relationship between the target and a feature is linear, monotonic or more complex.
#
# In scikit-learn, PDPs are implemented and available for certain algorithms, but at this point (version 0.20.0) they are not yet implemented for Random Forests. Thankfully, there is an add-on package called **PDPbox** (https://pdpbox.readthedocs.io/en/latest/) which adds this functionality to Random Forests. The package is easy to install through pip.

# %%
! pip install pdpbox
# Out:
# Collecting pdpbox
#   Obtaining dependency information for pdpbox from https://files.pythonhosted.org/packages/1f/2e/8f115e0c514f2057fd8a99a01f52a5cd7d6952adf98dcffae086c2bccff6/PDPbox-0.3.0-py3-none-any.whl.metadata
#   Downloading PDPbox-0.3.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: joblib>=1.1.0 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from pdpbox) (1.2.0)
# Requirement already satisfied: matplotlib>=3.6.2 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from pdpbox) (3.7.1)
# Requirement already satisfied: numpy>=1.21.5 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from pdpbox) (1.24.3)
# Requirement already satisfied: pandas>=1.4.4 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from pdpbox) (1.5.3)
# Requirement already satisfied: plotly>=5.9.0 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from pdpbox) (5.9.0)
# Collecting pqdm>=0.2.0 (from pdpbox)
#   Obtaining dependency information for pqdm>=0.2.0 from https://files.pythonhosted.org/packages/9e/b7/720988acdc9b5805cd1ef311aa75d6fd1c5438b87f4add1ec8d11f78d63b/pqdm-0.2.0-py2.py3-none-any.whl.metadata
#   Downloading pqdm-0.2.0-py2.py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: psutil>=5.9.0 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from pdpbox) (5.9.0)
# Requirement already satisfied: pytest in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from pdpbox) (7.4.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from pdpbox) (1.3.0)
# Requirement already satisfied: setuptools in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from pdpbox) (68.0.0)
# Requirement already satisfied: sphinx>=5.0.2 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from pdpbox) (5.0.2)
# Collecting sphinx-rtd-theme>=1.1.1 (from pdpbox)
#   Obtaining dependency information for sphinx-rtd-theme>=1.1.1 from https://files.pythonhosted.org/packages/ea/46/00fda84467815c29951a9c91e3ae7503c409ddad04373e7cfc78daad4300/sphinx_rtd_theme-2.0.0-py2.py3-none-any.whl.metadata
#   Downloading sphinx_rtd_theme-2.0.0-py2.py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: tqdm>=4.64.1 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from pdpbox) (4.65.0)
# Requirement already satisfied: numpydoc>=1.4.0 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from pdpbox) (1.5.0)
# Collecting xgboost>=1.7.1 (from pdpbox)
#   Obtaining dependency information for xgboost>=1.7.1 from https://files.pythonhosted.org/packages/99/a1/5219921a9bcb5388623f81908ff43d606aec2e512e0c02f6eb49f3b3caa8/xgboost-2.1.1-py3-none-macosx_12_0_arm64.whl.metadata
#   Downloading xgboost-2.1.1-py3-none-macosx_12_0_arm64.whl.metadata (2.1 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from matplotlib>=3.6.2->pdpbox) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from matplotlib>=3.6.2->pdpbox) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from matplotlib>=3.6.2->pdpbox) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from matplotlib>=3.6.2->pdpbox) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from matplotlib>=3.6.2->pdpbox) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from matplotlib>=3.6.2->pdpbox) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from matplotlib>=3.6.2->pdpbox) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from matplotlib>=3.6.2->pdpbox) (2.8.2)
# Requirement already satisfied: Jinja2>=2.10 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from numpydoc>=1.4.0->pdpbox) (3.1.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from pandas>=1.4.4->pdpbox) (2022.7)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from plotly>=5.9.0->pdpbox) (8.2.2)
# Collecting bounded-pool-executor (from pqdm>=0.2.0->pdpbox)
#   Obtaining dependency information for bounded-pool-executor from https://files.pythonhosted.org/packages/bc/23/72ecfe284a1da711257ff310b29c6667d0187a608322d58bf1c7a927c7b2/bounded_pool_executor-0.0.3-py3-none-any.whl.metadata
#   Downloading bounded_pool_executor-0.0.3-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: typing-extensions in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from pqdm>=0.2.0->pdpbox) (4.7.1)
# Requirement already satisfied: scipy>=1.5.0 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from scikit-learn>=1.0.2->pdpbox) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from scikit-learn>=1.0.2->pdpbox) (2.2.0)
# Requirement already satisfied: sphinxcontrib-applehelp in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from sphinx>=5.0.2->pdpbox) (1.0.2)
# Requirement already satisfied: sphinxcontrib-devhelp in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from sphinx>=5.0.2->pdpbox) (1.0.2)
# Requirement already satisfied: sphinxcontrib-jsmath in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from sphinx>=5.0.2->pdpbox) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from sphinx>=5.0.2->pdpbox) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from sphinx>=5.0.2->pdpbox) (1.1.5)
# Requirement already satisfied: sphinxcontrib-qthelp in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from sphinx>=5.0.2->pdpbox) (1.0.3)
# Requirement already satisfied: Pygments>=2.0 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from sphinx>=5.0.2->pdpbox) (2.15.1)
# Requirement already satisfied: docutils<0.19,>=0.14 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from sphinx>=5.0.2->pdpbox) (0.18.1)
# Requirement already satisfied: snowballstemmer>=1.1 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from sphinx>=5.0.2->pdpbox) (2.2.0)
# Requirement already satisfied: babel>=1.3 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from sphinx>=5.0.2->pdpbox) (2.11.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from sphinx>=5.0.2->pdpbox) (0.7.12)
# Requirement already satisfied: imagesize in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from sphinx>=5.0.2->pdpbox) (1.4.1)
# Requirement already satisfied: requests>=2.5.0 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from sphinx>=5.0.2->pdpbox) (2.31.0)
# Collecting sphinxcontrib-jquery<5,>=4 (from sphinx-rtd-theme>=1.1.1->pdpbox)
#   Obtaining dependency information for sphinxcontrib-jquery<5,>=4 from https://files.pythonhosted.org/packages/76/85/749bd22d1a68db7291c89e2ebca53f4306c3f205853cf31e9de279034c3c/sphinxcontrib_jquery-4.1-py2.py3-none-any.whl.metadata
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: iniconfig in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from pytest->pdpbox) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from pytest->pdpbox) (1.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from pytest->pdpbox) (1.0.4)
# Requirement already satisfied: tomli>=1.0.0 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from pytest->pdpbox) (2.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from Jinja2>=2.10->numpydoc>=1.4.0->pdpbox) (2.1.1)
# Requirement already satisfied: six>=1.5 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.6.2->pdpbox) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from requests>=2.5.0->sphinx>=5.0.2->pdpbox) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from requests>=2.5.0->sphinx>=5.0.2->pdpbox) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from requests>=2.5.0->sphinx>=5.0.2->pdpbox) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/samir.sebbah/miniconda3/envs/ucsd/lib/python3.10/site-packages (from requests>=2.5.0->sphinx>=5.0.2->pdpbox) (2024.7.4)
# Downloading PDPbox-0.3.0-py3-none-any.whl (35.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.8/35.8 MB 15.4 MB/s eta 0:00:0000:0100:01
# Downloading pqdm-0.2.0-py2.py3-none-any.whl (6.8 kB)
# Downloading sphinx_rtd_theme-2.0.0-py2.py3-none-any.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 19.5 MB/s eta 0:00:00a 0:00:01
# Downloading xgboost-2.1.1-py3-none-macosx_12_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 27.9 MB/s eta 0:00:00a 0:00:01
# Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 6.3 MB/s eta 0:00:00
# Downloading bounded_pool_executor-0.0.3-py3-none-any.whl (3.4 kB)
# Installing collected packages: bounded-pool-executor, pqdm, xgboost, sphinxcontrib-jquery, sphinx-rtd-theme, pdpbox
# Successfully installed bounded-pool-executor-0.0.3 pdpbox-0.3.0 pqdm-0.2.0 sphinx-rtd-theme-2.0.0 sphinxcontrib-jquery-4.1 xgboost-2.1.1

# %% [markdown]
# While we encourage you to read the documentation for the package (and reading package documentation in general is a good habit to develop), the authors of the package have also written an excellent blog post on how to use it, showing examples on different algorithms from scikit-learn (the Random Forests example is towards the end of the blog post): https://briangriner.github.io/Partial_Dependence_Plots_presentation-BrianGriner-PrincetonPublicLibrary-4.14.18-updated-4.22.18.html

# %% [markdown]
# So, armed with this new knowledge, feel free to pick a few features, and make a couple of Partial Dependence Plots of your own!

# %%
# Your code here!
from sklearn.inspection import partial_dependence
# TODO
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 # Your code here!
#       2 from sklearn.inspection import partial_dependence
# ----> 3 inspection.PartialDependenceDisplay()
#
# TypeError: PartialDependenceDisplay.__init__() missing 1 required positional argument: 'pd_results'

# %% [markdown]
# ## (Optional) Advanced Boosting-Based Algorithms

# %% [markdown]
# As explained in the video lectures, the next generation of algorithms after Random Forests (that use Bagging, a.k.a. Bootstrap Aggregation) were developed using Boosting, and the first one of these were Gradient Boosted Machines, which are implemented in scikit-learn (http://scikit-learn.org/stable/modules/ensemble.html#gradient-tree-boosting).

# %% [markdown]
# Still, in recent years, a number of variations on GBMs have been developed by different research amd industry groups, all of them bringing improvements, both in speed, accuracy and functionality to the original Gradient Boosting algorithms.
#
# In no order of preference, these are:
# 1. **XGBoost**: https://xgboost.readthedocs.io/en/latest/
# 2. **CatBoost**: https://tech.yandex.com/catboost/
# 3. **LightGBM**: https://lightgbm.readthedocs.io/en/latest/

# %% [markdown]
# If you're using the Anaconda distribution, these are all very easy to install:

# %%
! conda install -c anaconda py-xgboost

# %%
! conda install -c conda-forge catboost

# %%
! conda install -c conda-forge lightgbm

# %% [markdown]
# Your task in this optional section of the mini project is to read the documentation of these three libraries, and apply all of them to the "German Credit" dataset, just like you did in the case of Decision Trees and Random Forests.

# %% [markdown]
# The final deliverable of this section should be a table (can be a pandas DataFrame) which shows the accuracy of all the five algorthms taught in this mini project in one place.

# %% [markdown]
# Happy modeling! :)
